# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from datetime import datetime

now = datetime.now()
current_time = now.strftime("%Y%m%d_%H%M%S")

def fuzzy_match(string1, string2):
    return fuzz.ratio(string1, string2)

p1_sessions = pd.read_excel("C:\\Users\\subha\\Appen\\PE Project Report - 18806_Benchmarking\\Falcon_BC_P18806_collection_report.xlsx",  sheet_name='f2136663')
p2_sessions = pd.read_excel("C:\\Users\\subha\Appen\\PE Project Report - 18806_Benchmarking\\Falcon_BC_P18806_collection_report.xlsx", sheet_name='f2162731')

#p1_sessions = pd.read_excel("C:\\Users\\subha\\Appen\\P18806 Falcon Benchmarking Q2 2023 - Documents\\Data Collection\\Tracker\\Data_sources\\job_data.xlsx",  sheet_name='job1')
#p2_sessions = pd.read_excel("C:\\Users\\subha\\Appen\\P18806 Falcon Benchmarking Q2 2023 - Documents\\Data Collection\\Tracker\\Data_sources\\job_data.xlsx",  sheet_name='job2')


#picking cols
p1_cols=["session_name","_created_at","_started_at","p1_app","p1_os","device_p1_serial","test_account_id_p1","pin","video01_location","audio02_location","audio03_location",
         "audio04_location","audio05_location","audio06_location","word_1_p1_hear","word_2_p2_hear","word_3_p1_hear","word_4_p2_hear",
         "word_5_p1_hear","word_6_p2_hear","word_7_p1_hear","word_8_p2_hear","word_9_p1_hear","word_10_p2_hear",
         "word_11_p1_hear","word_12_p2_hear","word_1_p1_speak","word_2_p1_speak","word_3_p1_speak","word_4_p1_speak",
         "word_5_p1_speak","word_6_p1_speak","word_7_p1_speak","word_8_p1_speak","word_9_p1_speak","word_10_p1_speak",
         "word_11_p1_speak","word_12_p1_speak","call_start_time_task1_trial_1","call_end_time_task1_trial_1",
         "call_start_time_task1_trial_2","call_end_time_task1_trial_2","call_start_time_task1_trial_3",
         "call_end_time_task1_trial_3","wrd_type_time1","wrd_type_time2","wrd_type_time3","wrd_type_time4",
         "wrd_type_time5","wrd_type_time6","wrd_type_time7","wrd_type_time8","wrd_type_time9",
         "wrd_type_time10","wrd_type_time11","wrd_type_time12"]

p2_cols=["session_name","_created_at","_started_at","p1_app","p1_os","device_p2_serial","test_account_id_p2","pin","video01_location","video02_location",
         "video03_location","video04_location","video05_location","video06_location","word_1_p2_hear","word_2_p2_hear",
         "word_3_p2_hear","word_4_p2_hear","word_5_p2_hear","word_6_p2_hear","word_7_p2_hear","word_8_p2_hear",
         "word_9_p2_hear","word_10_p2_hear","word_11_p2_hear","word_12_p2_hear","word_1_p2_speak","word_2_p2_speak",
         "word_3_p2_speak","word_4_p2_speak","word_5_p2_speak","word_6_p2_speak","word_7_p2_speak","word_8_p2_speak",
         "word_9_p2_speak","word_10_p2_speak","word_11_p2_speak","word_12_p2_speak","call_start_time_task2_trial_1","call_end_time_task2_trial_1",
         "call_start_time_task2_trial_2","call_end_time_task2_trial_2","call_start_time_task2_trial_3",
         "call_end_time_task2_trial_3","wrd_type_time1","wrd_type_time2","wrd_type_time3","wrd_type_time4",
         "wrd_type_time5","wrd_type_time6","wrd_type_time7","wrd_type_time8","wrd_type_time9",
         "wrd_type_time10","wrd_type_time11","wrd_type_time12"]


p1_clean=p1_sessions[p1_cols]
p2_clean=p2_sessions[p2_cols]
#Correcting a data row
p1_clean.loc[p1_clean['pin'] == 10023, 'p1_os'] = 'Android'

#creating key col for marging
p1_clean["key_col"]=p1_clean["pin"].apply(str)+"-"+p1_clean["p1_app"]#+"-"+p1_clean["p1_os"]
p2_clean["key_col"]=p2_clean["pin"].apply(str)+"-"+p2_clean["p1_app"]#+"-"+p2_clean["p1_os"]

#marging
p1_plus_p2=p1_clean.merge(p2_clean, on='key_col', how='left')


#saving a merged file
#p1_plus_p2.to_excel("C:\\Users\\subha\\Desktop\\Appen\\Benchmarking\\merged.xlsx", index=False)
p1_plus_p2.to_excel("C:\\Users\\subha\\Appen\\P18806 Falcon Benchmarking Q2 2023 - Documents\\Data Collection\\Tracker\\Data_sources\\merged_{}.xlsx".format(current_time), index=False)


#p1_plus_p2 = p1_plus_p2.sort_values(by=['pin'], ascending=True)
#preparing to stack data
task_1_trial_1_col=["session_name_x","_created_at_x","_started_at_x","p1_app_x","p1_os_x","device_p1_serial","test_account_id_p1","pin_x","video01_location_x","video01_location_y","word_1_p1_speak","word_2_p1_speak","word_1_p2_hear","word_2_p2_hear_y","word_1_p2_speak","word_2_p2_speak","word_1_p1_hear","word_2_p2_hear_x","call_start_time_task1_trial_1","call_end_time_task1_trial_1","wrd_type_time1_y","wrd_type_time2_y","wrd_type_time1_x","wrd_type_time2_x","key_col","session_name_y","_created_at_y","_started_at_y","p1_app_y","p1_os_y","device_p2_serial","test_account_id_p2","pin_y"]
task_2_trial_1_col=["session_name_x","_created_at_x","_started_at_x","p1_app_x","p1_os_x","device_p1_serial","test_account_id_p1","pin_x","video02_location","audio02_location","word_3_p2_speak","word_4_p2_speak","word_3_p1_hear","word_4_p2_hear_x","word_3_p1_speak","word_4_p1_speak","word_3_p2_hear","word_4_p2_hear_y","call_start_time_task2_trial_1","call_end_time_task2_trial_1","wrd_type_time3_x","wrd_type_time4_x","wrd_type_time3_y","wrd_type_time4_y","key_col","session_name_y","_created_at_y","_started_at_y","p1_app_y","p1_os_y","device_p2_serial","test_account_id_p2","pin_y"]
task_1_trial_2_col=["session_name_x","_created_at_x","_started_at_x","p1_app_x","p1_os_x","device_p1_serial","test_account_id_p1","pin_x","audio03_location","video03_location","word_5_p1_speak","word_6_p1_speak","word_5_p2_hear","word_6_p2_hear_y","word_5_p2_speak","word_6_p2_speak","word_5_p1_hear","word_6_p2_hear_x","call_start_time_task1_trial_2","call_end_time_task1_trial_2","wrd_type_time5_y","wrd_type_time6_y","wrd_type_time5_x","wrd_type_time6_x","key_col","session_name_y","_created_at_y","_started_at_y","p1_app_y","p1_os_y","device_p2_serial","test_account_id_p2","pin_y"]
task_2_trial_2_col=["session_name_x","_created_at_x","_started_at_x","p1_app_x","p1_os_x","device_p1_serial","test_account_id_p1","pin_x","video04_location","audio04_location","word_7_p2_speak","word_8_p2_speak","word_7_p1_hear","word_8_p2_hear_x","word_7_p1_speak","word_8_p1_speak","word_7_p2_hear","word_8_p2_hear_y","call_start_time_task2_trial_2","call_end_time_task2_trial_2","wrd_type_time7_x","wrd_type_time8_x","wrd_type_time7_y","wrd_type_time8_y","key_col","session_name_y","_created_at_y","_started_at_y","p1_app_y","p1_os_y","device_p2_serial","test_account_id_p2","pin_y"]
task_1_trial_3_col=["session_name_x","_created_at_x","_started_at_x","p1_app_x","p1_os_x","device_p1_serial","test_account_id_p1","pin_x","audio05_location","video05_location","word_9_p1_speak","word_10_p1_speak","word_9_p2_hear","word_10_p2_hear_y","word_9_p2_speak","word_10_p2_speak","word_9_p1_hear","word_10_p2_hear_x","call_start_time_task1_trial_3","call_end_time_task1_trial_3","wrd_type_time9_y","wrd_type_time10_y","wrd_type_time9_x","wrd_type_time10_x","key_col","session_name_y","_created_at_y","_started_at_y","p1_app_y","p1_os_y","device_p2_serial","test_account_id_p2","pin_y"]
task_2_trial_3_col=["session_name_x","_created_at_x","_started_at_x","p1_app_x","p1_os_x","device_p1_serial","test_account_id_p1","pin_x","video06_location","audio06_location","word_11_p2_speak","word_12_p2_speak","word_11_p1_hear","word_12_p2_hear_x","word_11_p1_speak","word_12_p1_speak","word_11_p2_hear","word_12_p2_hear_y","call_start_time_task2_trial_3","call_end_time_task2_trial_3","wrd_type_time11_x","wrd_type_time12_x","wrd_type_time11_y","wrd_type_time12_y","key_col","session_name_y","_created_at_y","_started_at_y","p1_app_y","p1_os_y","device_p2_serial","test_account_id_p2","pin_y"]

task_1_trial_1=p1_plus_p2[task_1_trial_1_col]
task_2_trial_1=p1_plus_p2[task_2_trial_1_col]
task_1_trial_2=p1_plus_p2[task_1_trial_2_col]
task_2_trial_2=p1_plus_p2[task_2_trial_2_col]
task_1_trial_3=p1_plus_p2[task_1_trial_3_col]
task_2_trial_3=p1_plus_p2[task_2_trial_3_col]
#renaming cols as per the required output
task_1_trial_1.columns=["Session_ID","created_at_p1","started_at_p1","App","OS","P1_Device_ID","Test_Account_ID_P1","pin_p1","Audio_Filename_P1","Audio_Filename_P2","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Call_Start_Time","Call_End_Time","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating1","Time_word_Submitted_Rating2_fw","Time_word_Submitted_Rating2","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","P2_Device_ID","Test_Account_ID_P2","pin_p2"]
task_2_trial_1.columns=["Session_ID","created_at_p1","started_at_p1","App","OS","P1_Device_ID","Test_Account_ID_P1","pin_p1","Audio_Filename_P1","Audio_Filename_P2","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Call_Start_Time","Call_End_Time","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating1","Time_word_Submitted_Rating2_fw","Time_word_Submitted_Rating2","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","P2_Device_ID","Test_Account_ID_P2","pin_p2"]
task_1_trial_2.columns=["Session_ID","created_at_p1","started_at_p1","App","OS","P1_Device_ID","Test_Account_ID_P1","pin_p1","Audio_Filename_P1","Audio_Filename_P2","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Call_Start_Time","Call_End_Time","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating1","Time_word_Submitted_Rating2_fw","Time_word_Submitted_Rating2","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","P2_Device_ID","Test_Account_ID_P2","pin_p2"]
task_2_trial_2.columns=["Session_ID","created_at_p1","started_at_p1","App","OS","P1_Device_ID","Test_Account_ID_P1","pin_p1","Audio_Filename_P1","Audio_Filename_P2","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Call_Start_Time","Call_End_Time","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating1","Time_word_Submitted_Rating2_fw","Time_word_Submitted_Rating2","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","P2_Device_ID","Test_Account_ID_P2","pin_p2"]
task_1_trial_3.columns=["Session_ID","created_at_p1","started_at_p1","App","OS","P1_Device_ID","Test_Account_ID_P1","pin_p1","Audio_Filename_P1","Audio_Filename_P2","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Call_Start_Time","Call_End_Time","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating1","Time_word_Submitted_Rating2_fw","Time_word_Submitted_Rating2","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","P2_Device_ID","Test_Account_ID_P2","pin_p2"]
task_2_trial_3.columns=["Session_ID","created_at_p1","started_at_p1","App","OS","P1_Device_ID","Test_Account_ID_P1","pin_p1","Audio_Filename_P1","Audio_Filename_P2","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Call_Start_Time","Call_End_Time","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating1","Time_word_Submitted_Rating2_fw","Time_word_Submitted_Rating2","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","P2_Device_ID","Test_Account_ID_P2","pin_p2"]

task_1_trial_1["Rating_Type_Rating1"]="incoming"
task_1_trial_1["Rating_Type_Rating2"]="outgoing"
task_2_trial_1["Rating_Type_Rating1"]="outgoing"
task_2_trial_1["Rating_Type_Rating2"]="incoming"
task_1_trial_2["Rating_Type_Rating1"]="incoming"
task_1_trial_2["Rating_Type_Rating2"]="outgoing"
task_2_trial_2["Rating_Type_Rating1"]="outgoing"
task_2_trial_2["Rating_Type_Rating2"]="incoming"
task_1_trial_3["Rating_Type_Rating1"]="incoming"
task_1_trial_3["Rating_Type_Rating2"]="outgoing"
task_2_trial_3["Rating_Type_Rating1"]="outgoing"
task_2_trial_3["Rating_Type_Rating2"]="incoming"

task_1_trial_1["seq_task"]=1
task_2_trial_1["seq_task"]=2
task_1_trial_2["seq_task"]=1
task_2_trial_2["seq_task"]=2
task_1_trial_3["seq_task"]=1
task_2_trial_3["seq_task"]=2

stacked_=task_1_trial_1.append(task_2_trial_1)
stacked_=stacked_.append(task_1_trial_2)
stacked_=stacked_.append(task_2_trial_2)
stacked_=stacked_.append(task_1_trial_3)
stacked_=stacked_.append(task_2_trial_3)
stacked_ = stacked_.sort_values(by=['pin_p1','App'], ascending=True)
stacked_['sequence']=stacked_.groupby('pin_p1').cumcount()+1
stacked_['Call_ID']= stacked_['pin_p1'].apply(str)+"_"+stacked_['sequence'].apply(str)

#stacked_.drop(stacked_[stacked_['pin_p1'] != 5355].index, inplace = True)

## replace field that's entirely space (or empty) with NaN
#stacked_=stacked_.replace("", "NaN")

stacked_[["Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2"
]] = stacked_[["Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2"
]].astype(str) 

#stacked_[col_to_lower]=p1_plus_p2[col_to_lower].apply(lambda x: x.str.lower())
#stacked_.str.lower()
col_to_lower = ["Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2"]

stacked_[col_to_lower]=stacked_[col_to_lower].apply(lambda x: x.str.lower())

#Temporary cleaning/validation for test data

stacked_["Word_1_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_7', 'also', stacked_['Word_1_Spoken_Rating1'])
stacked_["Word_2_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_7', 'food', stacked_['Word_2_Spoken_Rating1'])

stacked_["Word_1_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_13', 'mine', stacked_['Word_1_Spoken_Rating1'])
stacked_["Word_1_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_15', 'nine', stacked_['Word_1_Spoken_Rating1'])
stacked_["Word_1_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_17', 'art', stacked_['Word_1_Spoken_Rating1'])

stacked_["Word_2_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_13', 'jet', stacked_['Word_2_Spoken_Rating1'])
stacked_["Word_2_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_15', 'ten', stacked_['Word_2_Spoken_Rating1'])
stacked_["Word_2_Spoken_Rating1"]=np.where(stacked_['Call_ID'] == '5355_17', 'egg', stacked_['Word_2_Spoken_Rating1'])

stacked_["Word_1_Spoken_Rating2"]=np.where(stacked_['Call_ID'] == '5355_14', 'fight', stacked_['Word_1_Spoken_Rating2'])
stacked_["Word_1_Spoken_Rating2"]=np.where(stacked_['Call_ID'] == '5355_16', 'bee', stacked_['Word_1_Spoken_Rating2'])
stacked_["Word_1_Spoken_Rating2"]=np.where(stacked_['Call_ID'] == '5355_18', 'tax', stacked_['Word_1_Spoken_Rating2'])

stacked_["Word_2_Spoken_Rating2"]=np.where(stacked_['Call_ID'] == '5355_14', 'fire', stacked_['Word_2_Spoken_Rating2'])
stacked_["Word_2_Spoken_Rating2"]=np.where(stacked_['Call_ID'] == '5355_16', 'saw', stacked_['Word_2_Spoken_Rating2'])
stacked_["Word_2_Spoken_Rating2"]=np.where(stacked_['Call_ID'] == '5355_18', 'flu', stacked_['Word_2_Spoken_Rating2'])

##from Sheena's output
stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10001_17', pd.to_datetime('06-27-2023  10:37:45'), stacked_['Call_Start_Time'])
stacked_["Call_End_Time"]=np.where(stacked_['Call_ID'] == '10001_17', pd.to_datetime('06-26-2023  10:37:45'), stacked_['Call_End_Time'])

stacked_["App"]=np.where(stacked_['Call_ID'] == '10002_19', 'Zoom', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10002_20', 'Zoom', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10002_21', 'Zoom', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10002_22', 'Zoom', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10002_23', 'Zoom', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10002_24', 'Zoom', stacked_['App'])

stacked_["App"]=np.where(stacked_['Call_ID'] == '10006_7', 'Instagram', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10006_8', 'Instagram', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10006_9', 'Instagram', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10006_10', 'Instagram', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10006_11', 'Instagram', stacked_['App'])
stacked_["App"]=np.where(stacked_['Call_ID'] == '10006_12', 'Instagram', stacked_['App'])

stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10016_21', pd.to_datetime('27-06-2023  17:36:09'), stacked_['Call_Start_Time'])
stacked_["Call_End_Time"]=np.where(stacked_['Call_ID'] == '10016_21', pd.to_datetime('27-06-2023  17:36:39'), stacked_['Call_End_Time'])

stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10026_21', pd.to_datetime('06-27-2023  17:50:25'), stacked_['Call_Start_Time'])
stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10034_16', pd.to_datetime('07-03-2023  10:48:50'), stacked_['Call_Start_Time'])
stacked_["Call_End_Time"]=np.where(stacked_['Call_ID'] == '10042_6', pd.to_datetime('07-04-2023  09:37:32'), stacked_['Call_End_Time'])
stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10047_5', pd.to_datetime('07-05-2023  08:34:25'), stacked_['Call_Start_Time'])
stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10047_9', pd.to_datetime('07-05-2023  07:56:35'), stacked_['Call_Start_Time'])

stacked_["Call_End_Time"]=np.where(stacked_['Call_ID'] == '10047_11', pd.to_datetime('07-05-2023  08:23:05'), stacked_['Call_End_Time'])
stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10051_21', pd.to_datetime('07-05-2023  14:53:01'), stacked_['Call_Start_Time'])
stacked_["Call_Start_Time"]=np.where(stacked_['Call_ID'] == '10607_8', pd.to_datetime('07-06-2023  09:26:30'), stacked_['Call_Start_Time'])

stacked_["Call_End_Time"]=np.where(stacked_['Call_ID'] == '10061_11', pd.to_datetime('07-07-2023  15:23:58'), stacked_['Call_End_Time'])

stacked_["Call_End_Time"]=np.where(stacked_['Call_ID'] == '10042_6', pd.to_datetime('07-04-2023  09:37:32'), stacked_['Call_End_Time'])


#fuzzy match
stacked_["Match_1_Rating1"]=stacked_.apply(lambda row: fuzzy_match(row['Word_1_Spoken_Rating1'], row['Word_1_Typed_Rating1']), axis=1)
stacked_["Match_2_Rating1"]=stacked_.apply(lambda row: fuzzy_match(row['Word_2_Spoken_Rating1'], row['Word_2_Typed_Rating1']), axis=1)
stacked_["Match_1_Rating2"]=stacked_.apply(lambda row: fuzzy_match(row['Word_1_Spoken_Rating2'], row['Word_1_Typed_Rating2']), axis=1)
stacked_["Match_2_Rating2"]=stacked_.apply(lambda row: fuzzy_match(row['Word_2_Spoken_Rating2'], row['Word_2_Typed_Rating2']), axis=1)

stacked_["Manual_QA_Rating1?"]=""
stacked_["Manual_QA_Rating2?"]=""
stacked_["Pass_Fail_Rating1"]=""
stacked_["Pass_Fail_Rating2"]=""


#pass fail
stacked_['Pass_Fail_Rating1'] = np.where((stacked_['Match_1_Rating1'] == 100) | (stacked_['Match_2_Rating1'] == 100), 'pass', stacked_['Pass_Fail_Rating1'])
stacked_['Pass_Fail_Rating2'] = np.where((stacked_['Match_1_Rating2'] == 100) | (stacked_['Match_2_Rating2'] == 100), 'pass', stacked_['Pass_Fail_Rating2'])

stacked_['Pass_Fail_Rating1'] = np.where((stacked_['Match_1_Rating1'] != 100) & (stacked_['Match_2_Rating1'] != 100), 'fail', stacked_['Pass_Fail_Rating1'])
stacked_['Pass_Fail_Rating2'] = np.where((stacked_['Match_1_Rating2'] != 100) & (stacked_['Match_2_Rating2'] != 100), 'fail', stacked_['Pass_Fail_Rating2'])


stacked_["Call_Start_Time"] = pd.to_datetime(stacked_.Call_Start_Time)
stacked_["Call_End_Time"] = pd.to_datetime(stacked_.Call_End_Time)
#DRopping test data
#stacked_.drop(stacked_[stacked_['Call_Start_Time'] < '2023-06-26'].index, inplace = True)
#stacked_.drop(stacked_[stacked_['pin_p1'] < 10001].index, inplace = True)





#columns in sequence
seq_col=["Call_ID","Session_ID","P1_Device_ID","P2_Device_ID","Test_Account_ID_P1","Test_Account_ID_P2","OS","App","Call_Start_Time","Call_End_Time","Rating_Type_Rating1","Pass_Fail_Rating1","Manual_QA_Rating1?","Time_word_Submitted_Rating1","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Match_1_Rating1","Match_2_Rating1","Rating_Type_Rating2","Pass_Fail_Rating2","Manual_QA_Rating2?","Time_word_Submitted_Rating2","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Match_1_Rating2","Match_2_Rating2","Audio_Filename_P1","Audio_Filename_P2","created_at_p1","started_at_p1","pin_p1","Time_word_Submitted_Rating1_fw","Time_word_Submitted_Rating2_fw","key_col","session_name_p2","created_at_p2","started_at_p2","App_p2","OS_p2","pin_p2","seq_task","sequence"]
stacked_=stacked_[seq_col]

final_output_col=["Call_ID","Session_ID","P1_Device_ID","P2_Device_ID","Test_Account_ID_P1","Test_Account_ID_P2","OS","App","Call_Start_Time","Call_End_Time","Rating_Type_Rating1","Pass_Fail_Rating1","Manual_QA_Rating1?","Time_word_Submitted_Rating1","Word_1_Spoken_Rating1","Word_2_Spoken_Rating1","Word_1_Typed_Rating1","Word_2_Typed_Rating1","Match_1_Rating1","Match_2_Rating1","Rating_Type_Rating2","Pass_Fail_Rating2","Manual_QA_Rating2?","Time_word_Submitted_Rating2","Word_1_Spoken_Rating2","Word_2_Spoken_Rating2","Word_1_Typed_Rating2","Word_2_Typed_Rating2","Match_1_Rating2","Match_2_Rating2","Audio_Filename_P1","Audio_Filename_P2","pin_p1","pin_p2"]

client_data_output=stacked_[final_output_col]

stacked_.to_excel("C:\\Users\\subha\\Appen\\P18806 Falcon Benchmarking Q2 2023 - Documents\\Data Collection\\Tracker\\Data_sources\\stacked_data_{}.xlsx".format(current_time), index=False)
client_data_output.to_excel("C:\\Users\\subha\\Appen\\P18806 Falcon Benchmarking Q2 2023 - Documents\\Data Collection\\Tracker\\Data_sources\\client_data_output_{}.xlsx".format(current_time), index=False)
print("done")

#client_data_output['sequence_1']=client_data_output.groupby('Session_ID').cumcount()+1

client_data_output["word_spocken_rating1"] = client_data_output["Word_1_Spoken_Rating1"]+","+client_data_output["Word_2_Spoken_Rating1"]
client_data_output["word_typed_rating1"] = client_data_output["Word_1_Typed_Rating1"]+","+client_data_output["Word_2_Typed_Rating1"]
client_data_output["word_spocken_rating2"] = client_data_output["Word_1_Spoken_Rating2"]+","+client_data_output["Word_2_Spoken_Rating2"]
client_data_output["word_typed_rating2"] = client_data_output["Word_1_Typed_Rating2"]+","+client_data_output["Word_2_Typed_Rating2"]

client_data_output_col1=["Call_ID","Session_ID","P1_Device_ID","P2_Device_ID","Test_Account_ID_P1","Test_Account_ID_P2","OS","App","Call_Start_Time","Call_End_Time","Rating_Type_Rating1","Pass_Fail_Rating1","Manual_QA_Rating1?","Time_word_Submitted_Rating1","word_spocken_rating1","word_typed_rating1","Audio_Filename_P1","Audio_Filename_P2"]
client_data_output_col2=["Call_ID","Session_ID","P1_Device_ID","P2_Device_ID","Test_Account_ID_P1","Test_Account_ID_P2","OS","App","Call_Start_Time","Call_End_Time","Rating_Type_Rating2","Pass_Fail_Rating2","Manual_QA_Rating2?","Time_word_Submitted_Rating2","word_spocken_rating2","word_typed_rating2","Audio_Filename_P1","Audio_Filename_P2"]
client_data_output_1=client_data_output[client_data_output_col1]
client_data_output_2=client_data_output[client_data_output_col2]

client_data_output_1['sequence_1']=client_data_output_1.groupby('Session_ID').cumcount()+1
client_data_output_2['sequence_1']=client_data_output_2.groupby('Session_ID').cumcount()+1

client_data_output_1.columns = ["Call_ID","Session_ID","Device_ID_Incoming","Device_ID_Outgoing","Test_Account_ID_Incoming","Test_Account_ID_Outgoing","OS","App","Call_Start_Time","Call_End_Time","Rating_Type","Rating_Result","Rating_Reviewed","Time_Words_Submitted","Words_Spoken","Words_Typed","Audio_Filename_Incoming","Audio_Filename_Outgoing","sequence_1"]
client_data_output_2.columns = ["Call_ID","Session_ID","Device_ID_Incoming","Device_ID_Outgoing","Test_Account_ID_Incoming","Test_Account_ID_Outgoing","OS","App","Call_Start_Time","Call_End_Time","Rating_Type","Rating_Result","Rating_Reviewed","Time_Words_Submitted","Words_Spoken","Words_Typed","Audio_Filename_Incoming","Audio_Filename_Outgoing","sequence_1"]

new_data_format = client_data_output_1.append(client_data_output_2)
new_data_format = new_data_format.sort_values(by=['sequence_1','Call_ID'],ascending=True)

new_data_format.to_excel("C:\\Users\\subha\\Appen\\P18806 Falcon Benchmarking Q2 2023 - Documents\\Data Collection\\Tracker\\Data_sources\\client_data_output_1setcol_format_{}.xlsx".format(current_time), index=False)
#new_data_format
# Out:
# C:\Users\subha\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\subha\AppData\Local\Temp/ipykernel_11116/352517474.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1_clean["key_col"]=p1_clean["pin"].apply(str)+"-"+p1_clean["p1_app"]#+"-"+p1_clean["p1_os"]
# C:\Users\subha\AppData\Local\Temp/ipykernel_11116/352517474.py:50: SettingWithCopyWarning:
# ...
