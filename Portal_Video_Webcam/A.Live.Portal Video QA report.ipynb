# %%
#from pandasgui import show
import pandas as pd
import requests
import os
import time
import zipfile
from datetime import datetime

def get_duplicates(row):
    working = qa_report[qa_report["ac_id"] == row.ac_id]
    working = working[working["session"] != row.session]
    objects_list = working["object"].unique()
    if row.object in objects_list:
        return row.object
    else:
        return "n"


job_id_appen='2004521' #Add job id
targetdir_appen=r'C:\Users\subha\Appen\Falcon Portal Video DC 2022 - General\01 Tracker\Source' #Add folder location
#targetdir_appen=r'C:\Users\subha\Desktop\Buir QA report test'
def get_QAreport(job_id,targetdir):
    job_id = job_id
    targetdir = targetdir
    
    
    headers = {'Authorization': 'Token token=pvgbMxCLGsS72ZwsnuYj'}
    data = {'type': 'full'}
    response = requests.post('https://api.appen.com/v1/jobs/'+job_id+'/regenerate', headers=headers, data=data)    
    print(response) #Just for debug
    #os.system(response)
    time.sleep(30)
    data = {'type': 'full'}
    response = requests.get('https://api.appen.com/v1/jobs/'+job_id+'.csv', headers=headers, data=data)   
    print(response) #Just for debug

    targetdir = targetdir

    with open(targetdir+"\\"+job_id+".zip", 'wb') as f:   #Saving the zip locally
        f.write(response.content)
    with zipfile.ZipFile(targetdir+"\\"+job_id +".zip","r") as zip_ref: #Extraction in folder
        zip_ref.extractall(targetdir)
    time.sleep(30)
    #os.remove(targetdir+"\\"+job_id+".zip")


get_QAreport(job_id_appen,targetdir_appen)  #Calling function


qa_report = pd.read_csv(targetdir_appen+"\\f"+job_id_appen+".csv")

#Time format correction
qa_report["_started_at"] = pd.to_datetime(qa_report._started_at)
qa_report.sort_values(by="_started_at",inplace=True, ascending=False)

# Drop duplicate session id
qa_report.drop_duplicates(keep="last",inplace=True,subset="session_id")

print("End of qa report")
# Organising stacking data

col1 = ["_unit_id","_created_at","_id","_started_at","_worker_id","_country","_region","_city","_ip","session_id","ac_id","qa_status_01",
"rejection_reason_01","input_comment_qa_01","durations","email","pass_check","phone_os","rowno","system_os","unit_id","video_01_url"]

col2 = ["_unit_id","_created_at","_id","_started_at","_worker_id","_country","_region","_city","_ip","session_id","ac_id","qa_status_02",
"rejection_reason_02","input_comment_qa_02","durations","email","pass_check","phone_os","rowno","system_os","unit_id","video_02_url"]

col3 = ["_unit_id","_created_at","_id","_started_at","_worker_id","_country","_region","_city","_ip","session_id","ac_id","qa_status_03",
"rejection_reason_03","input_comment_qa_03","durations","email","pass_check","phone_os","rowno","system_os","unit_id","video_03_url"]

col4 = ["_unit_id","_created_at","_id","_started_at","_worker_id","_country","_region","_city","_ip","session_id","ac_id","qa_status_04",
"rejection_reason_04","input_comment_qa_04","durations","email","pass_check","phone_os","rowno","system_os","unit_id","video_04_url"]

col5 = ["_unit_id","_created_at","_id","_started_at","_worker_id","_country","_region","_city","_ip","session_id","ac_id","qa_status_05",
"rejection_reason_05","input_comment_qa_05","durations","email","pass_check","phone_os","rowno","system_os","unit_id","video_05_url"]

col6 = ["_unit_id","_created_at","_id","_started_at","_worker_id","_country","_region","_city","_ip","session_id","ac_id","qa_status_06",
"rejection_reason_06","input_comment_qa_06","durations","email","pass_check","phone_os","rowno","system_os","unit_id","video_06_url"]

vid1=qa_report[col1]
vid2=qa_report[col2]
vid3=qa_report[col3]
vid4=qa_report[col4]
vid5=qa_report[col5]
vid6=qa_report[col6]
""""
vid1.rename(columns = {'qa_status_01':'qa_status'}, inplace = True)
vid1.rename(columns = {'rejection_reason_01':'rejection_reason'}, inplace = True)
vid1.rename(columns = {'input_comment':'input_comment_01'}, inplace = True)
vid1.rename(columns = {'video_01_url':'video_url'}, inplace = True)
vid1.rename(columns = {'qa_status_01':'qa_status'}, inplace = True)
"""

vid1["qa_status"]=vid1["qa_status_01"]
vid1["rejection_reason"]=vid1["rejection_reason_01"]
vid1["input_comment"]=vid1["input_comment_qa_01"]
vid1["video_url"]=vid1["video_01_url"]
vid1["video_name"]="video01"

#vid1.drop(['qa_status_01', 'rejection_reason_01','input_comment_qa_01','video_01_url'], axis=1)

vid2["qa_status"]=vid2["qa_status_02"]
vid2["rejection_reason"]=vid2["rejection_reason_02"]
vid2["input_comment"]=vid2["input_comment_qa_02"]
vid2["video_url"]=vid2["video_02_url"]
vid2["video_name"]="video02"

#vid2.drop(['qa_status_02', 'rejection_reason_02','input_comment_qa_02','video_02_url'], axis=1)

vid3["qa_status"]=vid3["qa_status_03"]
vid3["rejection_reason"]=vid3["rejection_reason_03"]
vid3["input_comment"]=vid3["input_comment_qa_03"]
vid3["video_url"]=vid3["video_03_url"]
vid3["video_name"]="video03"
#vid3.drop(['qa_status_03', 'rejection_reason_03','input_comment_qa_03','video_03_url'], axis=1)

vid4["qa_status"]=vid4["qa_status_04"]
vid4["rejection_reason"]=vid4["rejection_reason_04"]
vid4["input_comment"]=vid4["input_comment_qa_04"]
vid4["video_url"]=vid4["video_04_url"]
vid4["video_name"]="video04"

#vid4.drop(['qa_status_04', 'rejection_reason_04','input_comment_qa_04','video_04_url'], axis=1)

vid5["qa_status"]=vid5["qa_status_05"]
vid5["rejection_reason"]=vid5["rejection_reason_05"]
vid5["input_comment"]=vid5["input_comment_qa_05"]
vid5["video_url"]=vid5["video_05_url"]
vid5["video_name"]="video05"
#vid5.drop(['qa_status_05', 'rejection_reason_05','input_comment_qa_05','video_05_url'], axis=1)

vid6["qa_status"]=vid6["qa_status_06"]
vid6["rejection_reason"]=vid6["rejection_reason_06"]
vid6["input_comment"]=vid6["input_comment_qa_06"]
vid6["video_url"]=vid6["video_06_url"]
vid6["video_name"]="video06"
#vid6.drop(['qa_status_06', 'rejection_reason_06','input_comment_qa_06','video_06_url'], axis=1)


#Concat 3 dataframe
vid_df_temp = vid1.append([vid2,vid3,vid4,vid5,vid6])
vid_df = vid_df_temp[vid_df_temp['qa_status'] != '']
vid_df=vid_df.sort_values(['session_id','_started_at'],ascending=[True, False])

#SPlitting duration
"""
vid_df['durations']=vid_df['durations'].replace('{','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('}','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('_01','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('_02','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('_03','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('_04','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('_05','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('_06','',inplace=True)
vid_df['durations']=vid_df['durations'].replace('[^0-9,.]','',inplace=True)
"""
vid_df['dur']=vid_df['durations']
vid_df[['dur1','dur2','dur3','dur4','dur5','dur6']] = vid_df['dur'].str.split(',',expand=True)
#converting all to lower case
vid_df = vid_df.applymap(lambda s: s.lower() if type(s) == str else s)
final_col=["session_id","ac_id","_created_at","_started_at",
           "video_name","qa_status","rejection_reason","input_comment","video_url","system_os","durations","email","pass_check",
           "unit_id","_id","rowno","_unit_id","_worker_id","_country","_region","_city","_ip","acid_video"]


vid_df["acid_video"] = vid_df["ac_id"].astype(str) + "_" + vid_df["video_name"]

#vid_df.sort_values(by=['qa_status'], ascending=True)

#vid_df.drop_duplicates(keep="last",inplace=True,subset="acid_video")

vid_df_f=vid_df[final_col]
#vid_df.drop_duplicates(keep="last",inplace=True,subset="session_id")
vid_df_f.to_csv(targetdir_appen+"\Portal_Video_qa_report_stacked.csv", index=False)

# datetime object containing current date and time
now = datetime.now()
#print("now =", now)
# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)
# Out:
# <Response [200]>
# <Response [200]>
# End of qa report
# C:\Users\subha\AppData\Local\Temp/ipykernel_42716/3666493121.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vid1["qa_status"]=vid1["qa_status_01"]
# C:\Users\subha\AppData\Local\Temp/ipykernel_42716/3666493121.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vid1["rejection_reason"]=vid1["rejection_reason_01"]
# C:\Users\subha\AppData\Local\Temp/ipykernel_42716/3666493121.py:96: SettingWithCopyWarning:
# ...
